# %%
# %load_ext autoreload
# %autoreload 2
# %xmode Verbose
# %reset -f
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# Exception reporting mode: Verbose

# %%
from build_markdown import *
import pandas as pd
pd.set_option('display.max_rows', 30)
pd.set_option('display.max_columns', 30)

# %%
html_path = "resources/zoia_module_index.html"

# %%
df = read_and_clean(html_path)
# Out:
# <string>:7: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
# <string>:19: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
# <string>:20: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# ...

# %%
df.head(20)
# Out:
#              Category  Max # of Blocks Block #  Title of block  \
# 0   INTERFACE MODULES                2       1   pedal input L
# 1   INTERFACE MODULES             <NA>       2   pedal input R
# 2   INTERFACE MODULES             <NA>     NaN             NaN
# 3   INTERFACE MODULES                3       1  pedal output L
# 4   INTERFACE MODULES             <NA>       2  pedal output R
# 5   INTERFACE MODULES             <NA>      3*            gain
# 6   INTERFACE MODULES             <NA>     NaN             NaN
# 7   INTERFACE MODULES               32       1        note out
# 8   INTERFACE MODULES             <NA>       2        gate out
# 9   INTERFACE MODULES             <NA>      3*    velocity out
# 10  INTERFACE MODULES             <NA>      4*     trigger out
# 11  INTERFACE MODULES             <NA>     NaN             NaN
# 12  INTERFACE MODULES             <NA>     NaN             NaN
# 13  INTERFACE MODULES             <NA>     NaN             NaN
# ...

# %%
modules = slice_modules(df)
mods_df = pd.DataFrame([
    {
        "name":         m.name,
        "max_blocks":   pd.to_numeric(str(m.max_blocks).rstrip("*"), errors="coerce"),
        "avg_dsp":      pd.to_numeric(str(m.avg_dsp).rstrip("%"), errors="coerce"),
        "n_params":     len(m.parameters),
        "n_options":    len(m.options),
        "category":     m.category,
    }
    for m in modules
])

# %%
mods_df.describe()
# Out:
#        max_blocks    avg_dsp   n_params  n_options
# count   90.000000  88.000000  90.000000  90.000000
# mean     6.333333   4.281932   4.722222   1.888889
# std      7.257696   7.500702   2.804602   1.776529
# min      1.000000   0.010000   1.000000   0.000000
# 25%      2.000000   0.135000   3.000000   1.000000
# 50%      4.000000   0.700000   4.000000   1.000000
# 75%      8.000000   5.000000   8.000000   3.000000
# max     42.000000  45.000000  11.000000   8.000000

# %%
cats = build_categories(modules)

# %%
from IPython.display import Markdown, display

md_text = render_markdown(cats)
display(Markdown(md_text))
# Out:
# # ZOIA Module Index
#
# ## INTERFACE MODULES
# Interface modules will connect to and from your other music gear in the physical world. Synth modules, MIDI devices, audio sources, your DAW, footswitches, expression pedals, etc are all connected into ZOIA's button grid here.
#
# ### Audio Input
# Connect audio from the outside world into the grid. This could be a guitar, bass, synth module, computer audio, etc.
# - **Max Blocks:** `2`
# - **Avg DSP:** `0.4%`
# - **Connections:** `outputs, audio effect inputs, envelope follower, pitch detector, VCAs, sidechain inputs,`
# - **Options:**
#   - **`channels`** – `select presence of left input, right input, or both`
#   - **`input pad`** – `On the Euroburo, the input pad is set here (0, -6, -12dB)`
# - **Parameters:**
#   - **Block `1` – `pedal input L`**
#     - **Knob:** `no modifier`
#     - **Description:** `connects audio from left pedal input jack`
#     - **Option:** `channels`
#   - **Block `2` – `pedal input R`**
# ...
